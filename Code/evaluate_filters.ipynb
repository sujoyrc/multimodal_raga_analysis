# %%
import keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
model_path = '../Models/multi-scale-3/multi-scale-3-model_0.hdf5'

# %%
model = keras.models.load_model(model_path)

# %%
sns.heatmap(np.reshape(model.layers[1].get_weights()[0], (10, 64)))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(np.reshape(model.layers[2].get_weights()[0], (25, 32)))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(np.reshape(model.layers[3].get_weights()[0], (50, 32)))
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(np.reshape(model.layers[4].get_weights()[0], (100, 32)))
# Out:
# <AxesSubplot:>
